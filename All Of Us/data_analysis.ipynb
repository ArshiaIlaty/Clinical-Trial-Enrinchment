# %%
import pandas as pd

df = pd.read_csv('Person_Data_Refined.csv')

df.head()

df.info()

df.describe()

df.columns

df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504579 entries, 0 to 504578
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   person_id                          504579 non-null  int64
#  1   gender_concept_id                  504579 non-null  int64
#  2   gender                             504579 non-null  object
#  3   date_of_birth                      504579 non-null  object
#  4   race_concept_id                    504579 non-null  int64
#  5   race                               504579 non-null  object
#  6   ethnicity_concept_id               504579 non-null  int64
#  7   ethnicity                          504579 non-null  object
#  8   sex_at_birth_concept_id            504579 non-null  int64
#  9   sex_at_birth                       504579 non-null  object
#  10  self_reported_category_concept_id  504579 non-null  int64
# ...

# %%
df_id = df["person_id"]
df_id.head()
df_id.info()
df_id.describe()
df_id.shape
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 504579 entries, 0 to 504578
# Series name: person_id
# Non-Null Count   Dtype
# --------------   -----
# 504579 non-null  int64
# dtypes: int64(1)
# memory usage: 3.8 MB
# (504579,)

# %%
df_id.to_csv('Person_ID.csv', index=False)

# %%
import pandas as pd

# Load the list of 500k person_ids
person_ids_df = pd.read_csv('Person_ID.csv')

# Convert to set for fast lookup (recommended)
person_id_set = set(person_ids_df['person_id'])

person_id_set
# Out:
# {2097154,
#  3145730,
#  1048580,
#  3145734,
#  4194312,
#  2097162,
#  2097167,
#  1048594,
#  3145758,
#  6291493,
#  2097190,
#  1048615,
#  1048617,
#  6291498,
#  1048619,
#  2097196,
#  8388657,
#  1048627,
#  1048633,
#  1048634,
#  1048635,
#  3145789,
#  3145790,
#  1048638,
#  3145793,
#  2097220,
#  3145796,
#  9437253,
#  2097223,
#  1048656,
#  4194384,
#  1048659,
#  8388705,
#  3145826,
#  3145828,
#  2097254,
#  5242984,
#  8388713,
#  8388714,
#  2097259,
#  5242987,
#  3145838,
#  4194415,
#  2097263,
#  2097264,
#  2097266,
#  9437294,
#  1048693,
#  2097270,
#  3145848,
#  1048698,
#  8388733,
#  9437310,
#  1048708,
#  9437316,
#  9437317,
#  2097284,
#  3145866,
#  2097291,
#  5243019,
#  1048714,
#  1048718,
#  3145871,
#  3145873,
#  1048724,
#  1048727,
#  1048728,
#  5243032,
#  5243034,
#  1048732,
#  3145886,
#  9437343,
#  1048734,
#  6291617,
#  7340195,
#  1048740,
#  1048739,
#  3145895,
#  7340199,
#  5243049,
#  9437355,
#  6291628,
#  4194480,
# ...
